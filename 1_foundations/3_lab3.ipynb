# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# +34 663911866 (Mobile)
# ichamorroarias@gmail.com
# www.linkedin.com/in/
# imanolchamorro (LinkedIn)
# Top Skills
# Lenguaje unificado de modelado
# (UML)
# UML
# Python
# Languages
# German (Elementary)
# Spanish (Native or Bilingual)
# English (Full Professional)
# Certifications
# Learn Linux from basics to shell
# script
# UML and Object-Oriented Design
# Foundations
# Salesforce Administrator Certification
# TOEIC Certificate
# Python TOTAL: Advanced
# Programmer in 16 days
# Honors-Awards
# Mención Honorífica en Bachillerato
# Mención Honorífica en la asignatura
# de Vehículos Espaciales
# Imanol Chamorro Arias
# Validation, Integration and Testing Engineer | Aerospace Engineer -
# UPM | Postgraduate Organization Engineering, Project and Business
# Administration
# Greater Madrid Metropolitan Area
# Summary
# Aerospace Engineer working at Airbus Helicopters as a Test
# Engineer on behalf of ALTEN Germany in Bavaria. Doing and
# performing tests for different parts of the helicopter and making
# documentation after finishing the uploading of the new softare
# versions. The test are related to Bench testing. Also, Management
# of system requirements for the incorporation of a database model
# of helicopter components for the subsequent creation of tests in the
# future.
# Previously, I have worked as a systems engineer for Indra, in the
# ATM department. Performing management and specification of
# system and subsystem requirements.
# The specialty studied during the degree is Aerospace Vehicles,
# where tools such as CATIA, Matlab, ANSYS, Patran-Nastran are
# used.
# I did an internship at INTA as an engineer, where I participated in
# a project that developed a system for releasing a payload from the
# helicopter using tools such as Ultimaker Cura 3D for the design of
# the 3D parts of the release system, Arduino, CATIA or PCB design
# via DipTrace. Also, I have worked for Deloitte in its technology
# consulting, using the Salesforce tool in digital transformation both in
# Field Service and in implementation projects.
# I like to learn, so I continually try to train myself by taking courses
# on programming tools on my own, such as Python, with the aim
# of having advanced programming knowledge along with what I
# currently have in tools like Matlab.
# Interested in the world of digitalization and engineering, open to
# new horizons where I can learn new tools and participate in different
# projects related to the world of technology.
#   Page 1 of 4
# Experience
# GMV
# Validation, Integration and Testing Engineer
# July 2025 - Present (4 months)
# Madrid y alrededores
# ALTEN Germany
# System Engineer & Test Engineer in AIRBUS Helicopters
# September 2023 - July 2025 (1 year 11 months)
# Munich, Bavaria, Alemania
# Working as a Test Engineerin Airbus Helicopters on behalf of ALTEN testing
# Helicopter systems and making documentation about it.
# Experience in Test Bench, doing software test for different parts of the
# helicopter and try to resolve the errors and problems that it may has.
# Testing Database software updates for different parts of the helicopter and
# doing documentation to be presented and delivered to the other teams which
# are involved.
# Management of system requirements for the incorporation of a database
# model of helicopter components for the subsequent creation of tests in the
# future with DOORS.
# Writing and modifying requirement, as well as test scripts based on SCADE for
# the simulator and for testing the requirement modifications in the bech.
# Using DO-178 standards. Working on DAL-A.
# Also, finding solutions to solve problem requests for requirements with the new
# implementations the customer wants.
# Indra
# System Engineer
# February 2023 - September 2023 (8 months)
# San Fernando de Henares, Madrid, Spain
# Working collaboratively with multi-disciplinary teams to manage and specify
# system and sub-system requirements.
#   Page 2 of 4
# Involved in a project for DFS and LVNL  to help them with the requirements
# needed for the installation of the novel software developed by Indra for the Air
# Traffic Managment.
# The tool used for the management of the requirements was Rational DOORS,
# Rational Change and Excel.
# After the tests carried out for the new system updates, a study was carried out
# on how to implement and fix the errors produced during it. Collaborating with
# multiple teams inside the company for solving the problems and in continuous
# contact to found the better solutions regarding to the client request.
# Deloitte
# Technology Consultant
# September 2022 - February 2023 (6 months)
# Madrid, Comunidad de Madrid, España
# Working on international projects in the energy, real estate and
# telecommunications sectors. Working closely with multidisciplinary teams
# to understand specific business challenges and design solutions tailored to
# their needs. The projects were based in the implementation of Salesforce for
# simplify how to manage their management.
# Instituto Nacional de Técnica Aeroespacial. INTA
# System Engineer R&D Internship
# February 2022 - May 2022 (4 months)
# San Martín de la Vega, Madrid, Spain
# As an R&D engineer at the National Institute for Aerospace Technology
# (INTA), I had the opportunity to actively participate in research and
# development projects related to unmanned aerial vehicle (UAS) systems. My
# main responsibilities focused on the design of a payload release system for a
# UAS, using industry-leading tools. My key tasks included:
# Structural design with CATIA: I used CATIA software to carry out the structural
# design of the payload release system. This involved creating 3D models and
# then printing them on UltimakerCura using a 3D printer.
# Baseplate design with DipTrace: I used the DipTrace tool to design the
# baseplate for the system.
#   Page 3 of 4
# Research and development: I participated in research activities to identify
# and evaluate emerging technologies in the UAS field. I conducted extensive
# testing and analysis to ensure the efficiency and safety of the payload release
# system.
# Team collaboration: I worked closely with other engineers and scientists on
# multidisciplinary projects, sharing technical knowledge and experience to
# achieve project goals.
# Education
# Universidad Politécnica de Madrid
# Aerospace Engineer, Aerospace, aeronautical and astronautical
# engineering · (2017 - 2022)
# Universidad Europea
# Master's Degree in Organization Engineering, Project Management and
# Business, Ingeniería · (September 2024 - October 2025)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Imanol Chamorro"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Imanol Chamorro. You are answering questions on Imanol Chamorro's website, particularly questions related to Imanol Chamorro's career, background, skills and experience. Your responsibility is to represent Imanol Chamorro for interactions on the website as faithfully as possible. You are given a summary of Imanol Chamorro's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.\nI love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n+34 663911866 (Mobile)\nichamorroarias@gmail.com\nwww.linkedin.com/in/\nimanolchamorro (LinkedIn)\nTop Skills\nLenguaje unificado de modelado\n(UML)\nUML\nPython\nLanguages\nGerman (Elementary)\nSpanish (Native or Bilingual)\nEnglish (Full Professional)\nCertifications\nLearn Linux from basics to shell\nscript\nUML and Object-Oriented Design\nFoundations\nSalesforce Administrator Certification\nTOEIC Certificate\nPython TOTAL: Advanced\nProgrammer in 16 days\nHonors-Awards\nMención Honorífica en Bachillerato\nMención Honorífica en la asignatura\nde Vehículos Espaciales\nImanol Chamorro Arias\nValidation, Integration and Testing Engineer | Aerospace Engineer -\nUPM | Postgraduate Organization Engineering, Project and Business\nAdministration\nGreater Madrid Metropolitan Area\nSummary\nAerospace Engineer working at Airbus Helicopters as a Test\nEngineer on behalf of ALTEN Germany in Bavaria. Doing and\nperforming tests for different parts of the helicopter and making\ndocumentation after finishing the uploading of the new softare\nversions. The test are related to Bench testing. Also, Management\nof system requirements for the incorporation of a database model\nof helicopter components for the subsequent creation of tests in the\nfuture.\nPreviously, I have worked as a systems engineer for Indra, in the\nATM department. Performing management and specification of\nsystem and subsystem requirements.\nThe specialty studied during the degree is Aerospace Vehicles,\nwhere tools such as CATIA, Matlab, ANSYS, Patran-Nastran are\nused.\nI did an internship at INTA as an engineer, where I participated in\na project that developed a system for releasing a payload from the\nhelicopter using tools such as Ultimaker Cura 3D for the design of\nthe 3D parts of the release system, Arduino, CATIA or PCB design\nvia DipTrace. Also, I have worked for Deloitte in its technology\nconsulting, using the Salesforce tool in digital transformation both in\nField Service and in implementation projects.\nI like to learn, so I continually try to train myself by taking courses\non programming tools on my own, such as Python, with the aim\nof having advanced programming knowledge along with what I\ncurrently have in tools like Matlab.\nInterested in the world of digitalization and engineering, open to\nnew horizons where I can learn new tools and participate in different\nprojects related to the world of technology.\n\xa0 Page 1 of 4\xa0 \xa0\nExperience\nGMV\nValidation, Integration and Testing Engineer\nJuly 2025\xa0-\xa0Present\xa0(4 months)\nMadrid y alrededores\nALTEN Germany\nSystem Engineer & Test Engineer in AIRBUS Helicopters\nSeptember 2023\xa0-\xa0July 2025\xa0(1 year 11 months)\nMunich, Bavaria, Alemania\nWorking as a Test Engineerin Airbus Helicopters on behalf of ALTEN testing\nHelicopter systems and making documentation about it.\nExperience in Test Bench, doing software test for different parts of the\nhelicopter and try to resolve the errors an ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
#       2 You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
# ----> 3 The Agent is playing the role of {name} and is representing {name} on their website. \
#       4 The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
#       5 The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"
#       7 evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
#       8 evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."
#
# NameError: name 'name' is not defined

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("OPEN_AI_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = openai.beta.chat.completions.parse(model="gpt-4o-mini", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I currently do not hold any patents. My work has primarily focused on validation, integration, and testing within the aerospace engineering field, as well as system engineering and project management. I have been involved in various innovative projects, but none have yet led to a patent. If you have specific questions about my projects or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is acceptable as it directly answers the user's question about holding a patent. The Agent maintains a professional tone and provides relevant context about their experience in aerospace engineering and project management. Additionally, by inviting further questions, the Agent engages the user effectively, which is in line with the goal of being professional and engaging.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
